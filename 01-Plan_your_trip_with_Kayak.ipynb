# %% [markdown]
# ![Kayak](https://seekvectorlogo.com/wp-content/uploads/2018/01/kayak-vector-logo.png)
#
# # Plan your trip with Kayak
#
# ## Company's description 📇
#
# <a href="https://www.kayak.com" target="_blank">Kayak</a> is a travel search engine that helps user plan their next trip at the best price.
#
# The company was founded in 2004 by Steve Hafner & Paul M. English. After a few rounds of fundraising, Kayak was acquired by <a href="https://www.bookingholdings.com/" target="_blank">Booking Holdings</a> which now holds:
#
# * <a href="https://booking.com/" target="_blank">Booking.com</a>
# * <a href="https://kayak.com/" target="_blank">Kayak</a>
# * <a href="https://www.priceline.com/" target="_blank">Priceline</a>
# * <a href="https://www.agoda.com/" target="_blank">Agoda</a>
# * <a href="https://Rentalcars.com/" target="_blank">RentalCars</a>
# * <a href="https://www.opentable.com/" target="_blank">OpenTable</a>
#
# With over \$300 million revenue a year, Kayak operates in almost all countries and all languages to help their users book travels accros the globe.

# %% [markdown]
# ## Project 🚧
#
# The marketing team needs help on a new project. After doing some user research, the team discovered that **70% of their users who are planning a trip would like to have more information about the destination they are going to**.
#
# In addition, user research shows that **people tend to be defiant about the information they are reading if they don't know the brand** which produced the content.
#
# Therefore, Kayak Marketing Team would like to create an application that will recommend where people should plan their next holidays. The application should be based on real data about:
#
# * Weather
# * Hotels in the area
#
# The application should then be able to recommend the best destinations and hotels based on the above variables at any given time.

# %% [markdown]
# ## Goals 🎯
#
# As the project has just started, your team doesn't have any data that can be used to create this application. Therefore, your job will be to:
#
# * Scrape data from destinations
# * Get weather data from each destination
# * Get hotels' info about each destination
# * Store all the information above in a data lake
# * Extract, transform and load cleaned data from your datalake to a data warehouse

# %% [markdown]
# ## Scope of this project 🖼️
#
# Marketing team wants to focus first on the best cities to travel to in France. According <a href="https://one-week-in.com/35-cities-to-visit-in-france/" target="_blank">One Week In.com</a> here are the top-35 cities to visit in France:
#
# ```python
# ["Mont Saint Michel",
# "St Malo",
# "Bayeux",
# "Le Havre",
# "Rouen",
# "Paris",
# "Amiens",
# "Lille",
# "Strasbourg",
# "Chateau du Haut Koenigsbourg",
# "Colmar",
# "Eguisheim",
# "Besancon",
# "Dijon",
# "Annecy",
# "Grenoble",
# "Lyon",
# "Gorges du Verdon",
# "Bormes les Mimosas",
# "Cassis",
# "Marseille",
# "Aix en Provence",
# "Avignon",
# "Uzes",
# "Nimes",
# "Aigues Mortes",
# "Saintes Maries de la mer",
# "Collioure",
# "Carcassonne",
# "Ariege",
# "Toulouse",
# "Montauban",
# "Biarritz",
# "Bayonne",
# "La Rochelle"]
# ```
#
# Your team should focus **only on the above cities for your project**.

# %% [markdown]
# ## Helpers 🦮
#
# To help you achieve this project, here are a few tips that should help you
#
# ### Get weather data with an API
#
# *   Use https://nominatim.org/ to get the gps coordinates of all the cities (no subscription required) Documentation : https://nominatim.org/release-docs/develop/api/Search/
#
# *   Use https://openweathermap.org/appid (you have to subscribe to get a free apikey) and https://openweathermap.org/api/one-call-api to get some information about the weather for the 35 cities and put it in a DataFrame
#
# *   Determine the list of cities where the weather will be the nicest within the next 7 days For example, you can use the values of daily.pop and daily.rain to compute the expected volume of rain within the next 7 days... But it's only an example, actually you can have different opinions on a what a nice weather would be like 😎 Maybe the most important criterion for you is the temperature or humidity, so feel free to change the rules !
#
# *   Save all the results in a `.csv` file, you will use it later 😉 You can save all the informations that seem important to you ! Don't forget to save the name of the cities, and also to create a column containing a unique identifier (id) of each city (this is important for what's next in the project)
#
# *   Use plotly to display the best destinations on a map
#
# ### Scrape Booking.com
#
# Since BookingHoldings doesn't have aggregated databases, it will be much faster to scrape data directly from booking.com
#
# You can scrap as many information asyou want, but we suggest that you get at least:
#
# *   hotel name,
# *   Url to its booking.com page,
# *   Its coordinates: latitude and longitude
# *   Score given by the website users
# *   Text description of the hotel
#
#
# ### Create your data lake using S3
#
# Once you managed to build your dataset, you should store into S3 as a csv file.
#
# ### ETL
#
# Once you uploaded your data onto S3, it will be better for the next data analysis team to extract clean data directly from a Data Warehouse. Therefore, create a SQL Database using AWS RDS, extract your data from S3 and store it in your newly created DB.

# %% [markdown]
# ## Deliverable 📬
#
# To complete this project, your team should deliver:
#
# * A `.csv` file in an S3 bucket containing enriched information about weather and hotels for each french city
#
# * A SQL Database where we should be able to get the same cleaned data from S3
#
# * Two maps where you should have a Top-5 destinations and a Top-20 hotels in the area. You can use plotly or any other library to do so. It should look something like this:
#
# ![Map](https://full-stack-assets.s3.eu-west-3.amazonaws.com/images/Kayak_best_destination_project.png)

# %%
import pandas as pd
import requests
import pprint

# %%
# Create list of the 35 cities
cities = ["Mont Saint Michel",
"St Malo",
"Bayeux",
"Le Havre",
"Rouen",
"Paris",
"Amiens",
"Lille",
"Strasbourg",
"Chateau du Haut Koenigsbourg",
"Colmar",
"Eguisheim",
"Besancon",
"Dijon",
"Annecy",
"Grenoble",
"Lyon",
"Gorges du Verdon",
"Bormes les Mimosas",
"Cassis",
"Marseille",
"Aix en Provence",
"Avignon",
"Uzes",
"Nimes",
"Aigues Mortes",
"Saintes Maries de la mer",
"Collioure",
"Carcassonne",
"Ariege",
"Toulouse",
"Montauban",
"Biarritz",
"Bayonne",
"La Rochelle"]

# %%
# Store cities in a dataframe
df = pd.DataFrame(cities, columns=['City'])
df
# Out:
#                             City
# 0              Mont Saint Michel
# 1                        St Malo
# 2                         Bayeux
# 3                       Le Havre
# 4                          Rouen
# 5                          Paris
# 6                         Amiens
# 7                          Lille
# 8                     Strasbourg
# 9   Chateau du Haut Koenigsbourg
# 10                        Colmar
# 11                     Eguisheim
# 12                      Besancon
# 13                         Dijon
# 14                        Annecy
# 15                      Grenoble
# 16                          Lyon
# 17              Gorges du Verdon
# 18            Bormes les Mimosas
# 19                        Cassis
# 20                     Marseille
# 21               Aix en Provence
# 22                       Avignon
# 23                          Uzes
# 24                         Nimes
# 25                 Aigues Mortes
# 26      Saintes Maries de la mer
# 27                     Collioure
# 28                   Carcassonne
# 29                        Ariege
# 30                      Toulouse
# 31                     Montauban
# 32                      Biarritz
# 33                       Bayonne
# 34                   La Rochelle

# %% [markdown]
# ### Get weather data from each destination
# ##### Get weather data with an API
#
# *   Use https://nominatim.org/ to get the gps coordinates of all the cities (no subscription required) Documentation : https://nominatim.org/release-docs/develop/api/Search/
#
# *   Use https://openweathermap.org/appid (you have to subscribe to get a free apikey) and https://openweathermap.org/api/one-call-api to get some information about the weather for the 35 cities and put it in a DataFrame
#
# *   Determine the list of cities where the weather will be the nicest within the next 7 days For example, you can use the values of daily.pop and daily.rain to compute the expected volume of rain within the next 7 days... But it's only an example, actually you can have different opinions on a what a nice weather would be like 😎 Maybe the most important criterion for you is the temperature or humidity, so feel free to change the rules !
#
# *   Save all the results in a `.csv` file, you will use it later 😉 You can save all the informations that seem important to you ! Don't forget to save the name of the cities, and also to create a column containing a unique identifier (id) of each city (this is important for what's next in the project)
#
# *   Use plotly to display the best destinations on a map

# %% [markdown]
# ### I : Get GPS coordinates of 35 TOP cities from nominatim.org API

# %%
# Get info for one city, here Ariege
get_one_city = requests.get('https://nominatim.openstreetmap.org/search?q=Ariege&country=France&format=json&limit=1')
get_one_city.json()
# Out:
# [{'place_id': 281653603,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 7439,
#   'boundingbox': ['42.5732416', '43.3162514', '0.8267506', '2.1758135'],
#   'lat': '42.9455368',
#   'lon': '1.4065544156065486',
#   'display_name': 'Ariège, Occitanie, France métropolitaine, France',
#   'class': 'boundary',
#   'type': 'administrative',
#   'importance': 0.6009114788084189,
#   'icon': 'https://nominatim.openstreetmap.org/ui/mapicons//poi_boundary_administrative.p.20.png'}]

# %%
# get Lat and Lon for Ariege
print(get_one_city.json()[0]['lat'])
print(get_one_city.json()[0]['lon'])
# Out:
# 42.9455368
# 1.4065544156065486

# %%
list_lat = []
list_lon = []
for city in cities:
    city_encoded = city.replace(' ','+')
    info_city = requests.get('https://nominatim.openstreetmap.org/search?q={}&country=France&format=json&limit=1'.format(city_encoded))
    gps_data = info_city.json()
    if gps_data ==[]:
        list_lat.append('Null')
        list_lon.append('Null')
        print("Info for {} 'null' ".format(city))
    else:
        list_lat.append(gps_data[0]['lat'])
        list_lon.append(gps_data[0]['lon'])
        print("Info for {} ok".format(city))
# Out:
# Info for Mont Saint Michel ok
# Info for St Malo ok
# Info for Bayeux ok
# Info for Le Havre ok
# Info for Rouen ok
# Info for Paris ok
# Info for Amiens ok
# Info for Lille ok
# Info for Strasbourg ok
# Info for Chateau du Haut Koenigsbourg ok
# Info for Colmar ok
# Info for Eguisheim ok
# Info for Besancon ok
# Info for Dijon ok
# Info for Annecy ok
# Info for Grenoble ok
# Info for Lyon ok
# Info for Gorges du Verdon ok
# Info for Bormes les Mimosas ok
# Info for Cassis ok
# Info for Marseille ok
# Info for Aix en Provence ok
# Info for Avignon ok
# Info for Uzes ok
# Info for Nimes ok
# Info for Aigues Mortes ok
# Info for Saintes Maries de la mer ok
# Info for Collioure ok
# Info for Carcassonne ok
# Info for Ariege ok
# Info for Toulouse ok
# Info for Montauban ok
# Info for Biarritz ok
# Info for Bayonne ok
# Info for La Rochelle ok

# %%
print("List Lat :", list_lat)
print()
print("Len list lat:", len(list_lat))
print()
print("List Long :", list_lon)
print()
print("Len list lon:", len(list_lon))
# Out:
# List Lat : ['48.6359541', '48.649518', '49.2764624', '49.4938975', '49.4404591', '48.8588897', '49.8941708', '50.6365654', '48.584614', '48.249489800000006', '48.0777517', '48.0447968', '47.2380222', '47.3215806', '45.8992348', '45.1875602', '45.7578137', '43.7496562', '43.1572172', '43.2140359', '43.2961743', '43.5298424', '43.9492493', '44.0121279', '43.8374249', '43.5658225', '43.4522771', '42.52505', '43.2130358', '42.9455368', '43.6044622', '44.0175835', '43.471143749999996', '43.4933379', '46.1591126']
#
# Len list lat: 35
#
# List Long : ['-1.511459954959514', '-2.0260409', '-0.7024738', '0.1079732', '1.0939658', '2.3200410217200766', '2.2956951', '3.0635282', '7.7507127', '7.34429620253195', '7.3579641', '7.3079618', '6.0243622', '5.0414701', '6.1288847', '5.7357819', '4.8320114', '6.3285616', '6.329253867921363', '5.5396318', '5.3699525', '5.4474738', '4.8059012', '4.4196718', '4.3600687', '4.1912837', '4.4287172', '3.0831554', '2.3491069', '1.4065544156065486', '1.4442469', '1.3549991', '-1.552726590666314', '-1.475099', '-1.1520434']
#
# Len list lon: 35

# %%
# Create columns in df for coordinates of each cities
df['Latitude'] = None
df['Longitude'] = None

for i in df.index:
    df['Latitude'][i]= float(list_lat[i])
    df['Longitude'][i]= float(list_lon[i])
    
display(df)
# Out:
#                             City Latitude Longitude
# 0              Mont Saint Michel   48.636  -1.51146
# 1                        St Malo  48.6495  -2.02604
# 2                         Bayeux  49.2765 -0.702474
# 3                       Le Havre  49.4939  0.107973
# 4                          Rouen  49.4405   1.09397
# 5                          Paris  48.8589   2.32004
# 6                         Amiens  49.8942    2.2957
# 7                          Lille  50.6366   3.06353
# 8                     Strasbourg  48.5846   7.75071
# 9   Chateau du Haut Koenigsbourg  48.2495    7.3443
# 10                        Colmar  48.0778   7.35796
# 11                     Eguisheim  48.0448   7.30796
# 12                      Besancon   47.238   6.02436
# 13                         Dijon  47.3216   5.04147
# 14                        Annecy  45.8992   6.12888
# 15                      Grenoble  45.1876   5.73578
# 16                          Lyon  45.7578   4.83201
# 17              Gorges du Verdon  43.7497   6.32856
# 18            Bormes les Mimosas  43.1572   6.32925
# 19                        Cassis   43.214   5.53963
# 20                     Marseille  43.2962   5.36995
# 21               Aix en Provence  43.5298   5.44747
# 22                       Avignon  43.9492    4.8059
# 23                          Uzes  44.0121   4.41967
# 24                         Nimes  43.8374   4.36007
# 25                 Aigues Mortes  43.5658   4.19128
# 26      Saintes Maries de la mer  43.4523   4.42872
# 27                     Collioure  42.5251   3.08316
# 28                   Carcassonne   43.213   2.34911
# 29                        Ariege  42.9455   1.40655
# 30                      Toulouse  43.6045   1.44425
# 31                     Montauban  44.0176     1.355
# 32                      Biarritz  43.4711  -1.55273
# 33                       Bayonne  43.4933   -1.4751
# 34                   La Rochelle  46.1591  -1.15204

# %%
df['Latitude'] = df['Latitude'].astype(float)
df['Longitude'] = df['Longitude'].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   City       35 non-null     object
#  1   Latitude   35 non-null     float64
#  2   Longitude  35 non-null     float64
# dtypes: float64(2), object(1)
# memory usage: 968.0+ bytes

# %%
# extract df in csv file
df.to_csv('src/cities_coordgps.csv',index=False)

# %% [markdown]
# ### II : Get weather of 35 TOP cities from openweathermap.org API

# %%
API_key=""
API_key
# Out:
# '4f87f1b692a3452fb5da3993fa7a9d6d'

# %%
paris_coord = [df.Latitude[5],df.Longitude[5]]
paris_coord
# Out:
# [48.8588897, 2.3200410217200766]

# %%
## test to get weather for one destination
onecity_test = requests.get(f"https://api.openweathermap.org/data/2.5/onecall?lat={df.Latitude[5]}&lon={df.Longitude[5]}&exclude=hourly,current,minutely&appid={API_key}&units=metric&lang=fr")
onecity_test = onecity_test.json()
onecity_test
# Out:
# {'lat': 48.8589,
#  'lon': 2.32,
#  'timezone': 'Europe/Paris',
#  'timezone_offset': 3600,
#  'daily': [{'dt': 1643544000,
#    'sunrise': 1643527428,
#    'sunset': 1643561041,
#    'moonrise': 1643524260,
#    'moonset': 1643552100,
#    'moon_phase': 0.93,
#    'temp': {'day': 8.29,
#     'min': 5.1,
#     'max': 9.35,
#     'night': 5.71,
#     'eve': 6.65,
#     'morn': 5.69},
#    'feels_like': {'day': 8.29, 'night': 3.8, 'eve': 6.65, 'morn': 4.48},
#    'pressure': 1033,
#    'humidity': 64,
#    'dew_point': 1.64,
#    'wind_speed': 3.76,
#    'wind_deg': 274,
#    'wind_gust': 9.83,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'ciel dégagé',
#      'icon': '01d'}],
#    'clouds': 7,
#    'pop': 0.06,
#    'uvi': 1.15},
#   {'dt': 1643630400,
#    'sunrise': 1643613750,
#    'sunset': 1643647539,
#    'moonrise': 1643613780,
#    'moonset': 1643643180,
#    'moon_phase': 0.97,
#    'temp': {'day': 8.2,
#     'min': 4,
#     'max': 8.28,
#     'night': 4,
#     'eve': 5.5,
#     'morn': 6.48},
#    'feels_like': {'day': 4.63, 'night': 1.88, 'eve': 2.02, 'morn': 2.73},
#    'pressure': 1024,
#    'humidity': 54,
#    'dew_point': -0.78,
#    'wind_speed': 7.17,
#    'wind_deg': 309,
#    'wind_gust': 15.24,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'couvert',
#      'icon': '04d'}],
#    'clouds': 87,
#    'pop': 0.36,
#    'uvi': 1.11},
#   {'dt': 1643716800,
#    'sunrise': 1643700070,
#    'sunset': 1643734038,
#    'moonrise': 1643702580,
#    'moonset': 1643734680,
#    'moon_phase': 0,
#    'temp': {'day': 7.02,
#     'min': 3.19,
#     'max': 10.63,
#     'night': 10.34,
#     'eve': 9.61,
#     'morn': 4.13},
#    'feels_like': {'day': 4.05, 'night': 9.68, 'eve': 7.14, 'morn': 1.39},
#    'pressure': 1024,
#    'humidity': 93,
#    'dew_point': 5.79,
#    'wind_speed': 5.19,
#    'wind_deg': 306,
#    'wind_gust': 13.18,
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'légère pluie',
#      'icon': '10d'}],
#    'clouds': 100,
#    'pop': 0.71,
#    'rain': 0.66,
#    'uvi': 0.21},
#   {'dt': 1643803200,
#    'sunrise': 1643786388,
#    'sunset': 1643820537,
#    'moonrise': 1643790720,
#    'moonset': 1643826120,
#    'moon_phase': 0.05,
#    'temp': {'day': 10.82,
#     'min': 8.9,
#     'max': 10.82,
#     'night': 9.82,
#     'eve': 10.36,
#     'morn': 8.9},
#    'feels_like': {'day': 9.99, 'night': 9.5, 'eve': 9.41, 'morn': 6.38},
#    'pressure': 1026,
#    'humidity': 78,
#    'dew_point': 6.86,
#    'wind_speed': 5.47,
#    'wind_deg': 288,
#    'wind_gust': 13.57,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'couvert',
#      'icon': '04d'}],
#    'clouds': 99,
#    'pop': 0.05,
#    'uvi': 0.99},
#   {'dt': 1643889600,
#    'sunrise': 1643872704,
#    'sunset': 1643907036,
#    'moonrise': 1643878500,
#    'moonset': 1643917260,
#    'moon_phase': 0.08,
#    'temp': {'day': 10.33,
#     'min': 8.05,
#     'max': 11.05,
#     'night': 8.84,
#     'eve': 8.9,
#     'morn': 8.17},
#    'feels_like': {'day': 9.25, 'night': 6.8, 'eve': 7.25, 'morn': 6.58},
#    'pressure': 1018,
#    'humidity': 70,
#    'dew_point': 4.9,
#    'wind_speed': 3.83,
#    'wind_deg': 221,
#    'wind_gust': 8.67,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'couvert',
#      'icon': '04d'}],
#    'clouds': 100,
#    'pop': 0,
#    'uvi': 1.21},
#   {'dt': 1643976000,
#    'sunrise': 1643959018,
#    'sunset': 1643993536,
#    'moonrise': 1643965980,
#    'moonset': 1644008220,
#    'moon_phase': 0.12,
#    'temp': {'day': 8.56,
#     'min': 5.65,
#     'max': 8.78,
#     'night': 5.65,
#     'eve': 6.59,
#     'morn': 8.25},
#    'feels_like': {'day': 5.64, 'night': 2.85, 'eve': 4, 'morn': 5.45},
#    'pressure': 1020,
#    'humidity': 58,
#    'dew_point': 0.53,
#    'wind_speed': 5.38,
#    'wind_deg': 301,
#    'wind_gust': 13.13,
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'légère pluie',
#      'icon': '10d'}],
#    'clouds': 96,
#    'pop': 1,
#    'rain': 1.72,
#    'uvi': 2},
#   {'dt': 1644062400,
#    'sunrise': 1644045330,
#    'sunset': 1644080036,
#    'moonrise': 1644053400,
#    'moonset': 1644099000,
#    'moon_phase': 0.15,
#    'temp': {'day': 9.39,
#     'min': 4.37,
#     'max': 10.25,
#     'night': 7.98,
#     'eve': 9.43,
#     'morn': 4.37},
#    'feels_like': {'day': 7.23, 'night': 5.37, 'eve': 7.41, 'morn': 1.94},
#    'pressure': 1029,
#    'humidity': 66,
#    'dew_point': 3.19,
#    'wind_speed': 4.31,
#    'wind_deg': 239,
#    'wind_gust': 10.57,
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'peu nuageux',
#      'icon': '02d'}],
#    'clouds': 18,
#    'pop': 0,
#    'uvi': 2},
#   {'dt': 1644148800,
#    'sunrise': 1644131641,
#    'sunset': 1644166535,
#    'moonrise': 1644140760,
#    'moonset': 0,
#    'moon_phase': 0.18,
#    'temp': {'day': 10.97,
#     'min': 5.9,
#     'max': 11.67,
#     'night': 10.76,
#     'eve': 11.27,
#     'morn': 5.9},
#    'feels_like': {'day': 9.74, 'night': 9.82, 'eve': 10.25, 'morn': 2.36},
#    'pressure': 1029,
#    'humidity': 62,
#    'dew_point': 3.74,
#    'wind_speed': 6.06,
#    'wind_deg': 253,
#    'wind_gust': 14.52,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'couvert',
#      'icon': '04d'}],
#    'clouds': 91,
#    'pop': 0,
#    'uvi': 2}],
#  'alerts': [{'sender_name': 'METEO-FRANCE',
#    'event': 'Moderate wind warning',
#    'start': 1643554800,
#    'end': 1643641200,
#    'description': 'Although rather usual in this region, locally or potentially dangerous phenomena are expected. (such as local winds, summer thunderstorms, rising streams or high waves)',
#    'tags': ['Wind']}]}

# %%
# Get weather data for each cities and for keep_keys in the request
df_weather = []
days = 8

for index in range(df.shape[0]):
    for j in range(days):
        r = requests.get(f"https://api.openweathermap.org/data/2.5/onecall?lat={df.Latitude[index]}&lon={df.Longitude[index]}&exclude=hourly,current,minutely&appid={API_key}&units=metric").json()
        city = df.City[index]
        lat = df.Latitude[index]
        lon = df.Longitude[index]
        day = j
        d = r['daily']
        date = datetime.fromtimestamp(d[j]['dt']).strftime('%d/%m/%Y')
        tem_day = d[j]['temp']['day']
        feelslike_day = d[j]['feels_like']['day']
        pressure = d[j]['pressure']
        humidity = d[j]['humidity']
        wind_speed = d[j]['wind_speed']
        weather_main = d[j]['weather'][0]['main']
        weather_desc = d[j]['weather'][0]['description']
        prob_rain = d[j]['pop']
        clouds = d[j]['clouds']
        uvi = d[j]['uvi']
        df_weather.append([city, lat, lon, day, date, tem_day, feelslike_day, pressure, humidity, wind_speed, weather_main, weather_desc, prob_rain, clouds, uvi])

# %%
# Create a dataframe with df_weather
keep_keys = ["city", "Latitude", "Longitude", "day", "date", "tem_day", "feelslike_day", "pressure", "humidity", "wind_speed", "weather_main", "weather_desc", "prob_rain", "clouds", "uvi"]
df_weather_35 = pd.DataFrame(df_weather1, columns=keep_keys)
df_weather_35
# Out:
#                              city   Latitude  Longitude  day        date  \
# 0               Mont Saint Michel  48.635954  -1.511460    0  30/01/2022
# 1               Mont Saint Michel  48.635954  -1.511460    1  31/01/2022
# 2               Mont Saint Michel  48.635954  -1.511460    2  01/02/2022
# 3               Mont Saint Michel  48.635954  -1.511460    3  02/02/2022
# 4               Mont Saint Michel  48.635954  -1.511460    4  03/02/2022
# 5               Mont Saint Michel  48.635954  -1.511460    5  04/02/2022
# 6               Mont Saint Michel  48.635954  -1.511460    6  05/02/2022
# 7               Mont Saint Michel  48.635954  -1.511460    7  06/02/2022
# 8                         St Malo  48.649518  -2.026041    0  30/01/2022
# 9                         St Malo  48.649518  -2.026041    1  31/01/2022
# 10                        St Malo  48.649518  -2.026041    2  01/02/2022
# 11                        St Malo  48.649518  -2.026041    3  02/02/2022
# 12                        St Malo  48.649518  -2.026041    4  03/02/2022
# 13                        St Malo  48.649518  -2.026041    5  04/02/2022
# 14                        St Malo  48.649518  -2.026041    6  05/02/2022
# 15                        St Malo  48.649518  -2.026041    7  06/02/2022
# 16                         Bayeux  49.276462  -0.702474    0  30/01/2022
# 17                         Bayeux  49.276462  -0.702474    1  31/01/2022
# 18                         Bayeux  49.276462  -0.702474    2  01/02/2022
# 19                         Bayeux  49.276462  -0.702474    3  02/02/2022
# 20                         Bayeux  49.276462  -0.702474    4  03/02/2022
# 21                         Bayeux  49.276462  -0.702474    5  04/02/2022
# 22                         Bayeux  49.276462  -0.702474    6  05/02/2022
# 23                         Bayeux  49.276462  -0.702474    7  06/02/2022
# 24                       Le Havre  49.493898   0.107973    0  30/01/2022
# 25                       Le Havre  49.493898   0.107973    1  31/01/2022
# 0       9.34           9.34      1033        73        5.33       Clouds
# 1       7.93           4.10      1030        77        8.85         Rain
# 2       9.85           6.87      1028        94        8.08         Rain
# 3      10.78          10.11      1028        84        7.10       Clouds
# 4       7.77           4.90      1018        87        4.76       Clouds
# 5       8.17           4.57      1024        62        7.05         Rain
# 6      10.09           9.11      1030        75        5.54         Rain
# 7      11.23          10.42      1031        77        6.58       Clouds
# 8       8.54           7.74      1034        76        6.09       Clouds
# 9       8.18           4.12      1031        75       10.30       Clouds
# 10     10.03           9.49      1029        92        9.96       Clouds
# 11     10.18           9.45      1028        84        7.50        Clear
# 12      8.59           5.50      1018        85        5.87         Rain
# 13      8.42           4.97      1024        63        8.13         Rain
# 14      9.91           6.99      1030        75        6.45         Rain
# 15     11.13          10.34      1031        78        7.72       Clouds
# 16      8.78           8.78      1033        69        5.75       Clouds
# 17      7.66           3.54      1028        68        9.28         Rain
# 18     10.73          10.16      1026        88        8.33         Rain
# 19     11.87          11.20      1027        80        7.27       Clouds
# 20      7.95           4.85      1018        83        6.32       Clouds
# 21      7.67           3.94      1023        60        8.21         Rain
# 22     10.33           9.40      1028        76        7.13         Rain
# 23     10.50           9.75      1029        82        9.85       Clouds
# 24      7.81           7.81      1033        69        6.92       Clouds
# 25      7.90           3.41      1027        66       12.13         Rain
# 26      9.58           6.17      1025        93       10.33         Rain
# 27      9.60           7.09      1027        91        9.18       Clouds
# 28      7.54           4.06      1018        84        7.42         Rain
# 29      7.69           3.63      1022        59        8.74         Rain
# 30      9.27           6.04      1028        84        7.97         Rain
# 31      9.79           5.89      1029        84       10.26       Clouds
# 32      8.19           8.19      1033        69        4.52        Clear
# 33      7.56           3.42      1026        65        9.62         Rain
# 34      9.39           6.42      1024        94        9.02         Rain
# 35     10.77          10.07      1026        83        7.27       Clouds
# 36      8.36           5.38      1018        81        5.41       Clouds
# 37      7.52           3.66      1021        61        7.29         Rain
# 38      9.95           7.04      1028        75        6.45         Rain
# 39     10.90          10.08      1028        78        8.85       Clouds
# 40      8.29           8.29      1033        64        3.76        Clear
# 41      8.20           4.63      1024        54        7.17       Clouds
# 42      7.02           4.05      1024        93        5.19         Rain
# 43     10.82           9.99      1026        78        5.47       Clouds
# 44     10.33           9.25      1018        70        3.83       Clouds
# 45      8.56           5.64      1020        58        5.38         Rain
# 46      9.39           7.23      1029        66        4.31       Clouds
# 47     10.97           9.74      1029        62        6.06       Clouds
# 48      7.45           7.45      1033        71        4.61       Clouds
# 49      6.66           1.84      1023        65       10.32         Rain
# 50      8.96           5.73      1021        92        9.36       Clouds
# 51     11.31          10.61      1024        81        8.34       Clouds
# 52      9.15           6.26      1017        80        5.71       Clouds
# 53      7.02           2.93      1019        60        8.09         Rain
# 54      9.66           6.65      1027        71        7.60         Rain
# 55     10.60           9.75      1026        78        9.71       Clouds
# 56      7.53           7.53      1033        67        5.17       Clouds
# 57      6.19           1.30      1021        57       10.35         Rain
# 58      8.74           5.56      1019        89        8.07         Rain
# 59     11.03          10.30      1023        81        7.74       Clouds
# 60      8.86           6.05      1017        78        5.62       Clouds
# 61      6.79           2.84      1018        58        6.91         Rain
# 62      9.84           6.81      1025        68        7.65       Clouds
# 63     10.30           9.47      1023        80       11.38       Clouds
# 64      7.61           5.39      1032        63        4.99         Rain
# 65      4.94           0.24      1018        73        8.91         Rain
# 66      4.23           0.15      1025        65        6.49         Rain
# 67      6.69           5.23      1022        96        5.27         Rain
# 68      9.79           9.36      1019        78        2.83         Rain
# 69     10.13           9.05      1016        71        6.67         Rain
# 70      6.86           4.11      1030        65        4.08       Clouds
# 71      9.12           5.94      1030        63        6.57       Clouds
# 72      4.22           2.04      1032        74        2.43         Rain
# 73      1.76          -3.44      1019        80        7.31         Snow
# 74      0.90          -2.63      1025        69        3.87         Snow
# 75      5.12           2.39      1022        93        3.77         Rain
# 76      7.41           7.41      1018        78        1.76         Rain
# 77      6.92           3.89      1017        77        5.04         Rain
# 78      3.75           2.25      1030        70        2.36       Clouds
# 79      5.65           2.42      1030        67        4.45       Clouds
# 80      8.43           8.43      1032        69        3.17         Rain
# 81      4.63           0.79      1019        80        7.30         Snow
# 82      4.22           0.99      1026        64        4.79         Snow
# 83      7.47           5.41      1022        91        3.38         Rain
# 84     10.35           9.40      1019        75        1.91         Rain
# 85      9.77           7.36      1017        78        4.85         Rain
# 86      7.36           6.32      1030        64        2.17       Clouds
# 87      8.43           5.88      1031        66        4.41       Clouds
# 88      8.64           8.64      1032        68        2.89         Rain
# 89      4.50           0.81      1019        81        7.15         Snow
# 90      4.28           1.35      1026        64        4.34         Snow
# 91      7.49           5.50      1022        91        3.23         Rain
# 92     10.40           9.45      1019        75        1.89         Rain
# 93      9.57           7.34      1017        79        4.30         Rain
# 94      7.52           6.95      1030        64        2.13       Clouds
# 95      8.28           5.95      1031        66        3.88       Clouds
# 96      7.37           6.44      1033        87        2.59         Rain
# 97      4.05           0.04      1023        94        6.12         Snow
# 98      3.66           0.67      1028        72        5.85         Snow
# 99      6.13           3.44      1026        98        5.77         Rain
# 100     9.59           9.59      1019        78        3.07         Rain
# 101     8.87           6.06      1020        86        5.61         Rain
# 102     6.76           6.76      1031        69        1.40       Clouds
# 103     7.21           4.53      1034        73        4.08       Clouds
# 104     8.03           6.39      1033        83        2.64       Clouds
# 105     6.53           2.56      1023        71        7.88         Snow
# 106     4.60           1.89      1028        73        5.35         Rain
# 107     7.97           5.09      1026        94        6.37         Rain
# 108    10.00          10.00      1019        77        2.89       Clouds
# 109    10.09           9.17      1020        77        6.37         Rain
# 110     7.38           6.47      1031        66        2.55       Clouds
# 111     8.53           6.07      1033        68        4.27       Clouds
# 112     7.70           6.37      1031        78        2.67       Clouds
# 113     4.44           3.14      1024        86        1.67         Snow
# 114     3.23           0.78      1028        66        2.53         Snow
# 115     4.55           4.55      1028        99        1.52         Snow
# 116     9.26           9.26      1019        85        1.66       Clouds
# 117     8.27           8.27      1022        85        1.41         Rain
# 118     6.31           4.79      1029        71        2.11         Rain
# 119     8.21           8.21      1033        60        1.11       Clouds
# 120     8.84           6.77      1030        74        3.85       Clouds
# 121     6.36           4.41      1024        85        3.29         Snow
# 244    11.37          10.16      1022        61        4.72       Clouds
# 245    10.22           9.52      1025        85        4.53         Rain
# 246    10.30           8.87      1030        57        4.42       Clouds
# 247     9.22           8.23      1035        56        2.94        Clear
# 248    10.27           9.21      1032        71        3.88        Clear
# 249     8.46           5.37      1029        88        7.47       Clouds
# 250     5.79           2.08      1033        82        7.15       Clouds
# 251    11.96          11.17      1030        75        5.97       Clouds
# 252    11.28          10.13      1021        64        4.25       Clouds
# 253    10.61           9.95      1025        85        4.64         Rain
# 254     9.81           7.94      1030        58        3.91        Clear
# 255     8.91           7.81      1035        59        2.38        Clear
# 256     9.04           7.23      1032        72        3.22        Clear
# 257    11.31          10.59      1032        80        6.54         Rain
# 258     8.07           8.07      1035        74        5.33         Rain
# 259    12.25          11.44      1029        73        3.98       Clouds
# 260    12.19          11.53      1023        79        5.50       Clouds
# 261    11.43          10.85      1026        85        4.01         Rain
# 262     9.08           9.08      1031        79        2.88         Rain
# 263     9.73           8.56      1035        58        3.08        Clear
# 264     9.50           7.85      1033        72        3.11        Clear
# 265    11.77          11.07      1032        79        5.92         Rain
# 266     8.55           8.55      1035        73        4.33         Rain
# 267    12.90          12.10      1029        71        3.93       Clouds
# 268    12.46          11.82      1023        79        5.63       Clouds
# 269    11.74          11.19      1026        85        3.83         Rain
# 270     9.72           9.72      1031        79        2.82         Rain
# 271    10.31           8.86      1035        56        2.86        Clear
# 272     8.67           8.07      1034        88        4.87       Clouds
# 273     9.07           5.80      1031        72        6.98         Rain
# 274     9.55           6.42      1031        86        6.89       Clouds
# 275    10.32           9.34      1029        74        4.52       Clouds
# 276     9.21           7.09      1021        83        4.59         Rain
# 277     9.35           6.48      1024        90        5.82         Rain
# 278     7.50           6.55      1033        70        2.60        Clear
# 279     9.18           7.01      1035        78        3.96       Clouds
#
#          weather_desc  prob_rain  clouds   uvi
# 0       broken clouds       0.04      61  1.25
# 1          light rain       0.40      95  0.65
# 2          light rain       0.20     100  1.46
# 3    scattered clouds       0.00      35  1.38
# 4     overcast clouds       0.00     100  1.09
# 5          light rain       0.75      69  2.00
# 6          light rain       0.36      71  2.00
# 7     overcast clouds       0.00      97  2.00
# 8       broken clouds       0.16      57  1.24
# 9     overcast clouds       0.24      99  0.59
# 10    overcast clouds       0.05      98  1.47
# 11          clear sky       0.00       8  1.37
# 12         light rain       0.20     100  1.14
# 13         light rain       0.88      58  2.00
# 14         light rain       0.24      63  2.00
# 15    overcast clouds       0.00      95  2.00
# 16   scattered clouds       0.00      44  1.18
# 17         light rain       0.33     100  0.71
# 18         light rain       0.39     100  0.97
# 19         few clouds       0.00      24  1.33
# 20    overcast clouds       0.00     100  0.66
# 21         light rain       0.99      55  1.00
# 22         light rain       0.35      48  1.00
# 23    overcast clouds       0.00     100  1.00
# 24         few clouds       0.00      17  1.16
# 25         light rain       0.46     100  1.04
# 26         light rain       0.68     100  0.86
# 27      broken clouds       0.00      67  1.34
# 28         light rain       0.20     100  0.73
# 29         light rain       0.98      61  1.00
# 30         light rain       0.34      52  1.00
# 31    overcast clouds       0.00      97  1.00
# 32          clear sky       0.00       9  1.14
# 33         light rain       0.69      91  1.15
# 34         light rain       0.74     100  0.42
# 35    overcast clouds       0.00      87  1.26
# 36    overcast clouds       0.00     100  1.03
# 37         light rain       0.76      62  2.00
# 38         light rain       0.26      30  2.00
# 39    overcast clouds       0.00      90  2.00
# 40          clear sky       0.06       7  1.15
# 41    overcast clouds       0.36      87  1.11
# 42         light rain       0.71     100  0.21
# 43    overcast clouds       0.05      99  0.99
# 44    overcast clouds       0.00     100  1.21
# 45         light rain       1.00      96  2.00
# 46         few clouds       0.00      18  2.00
# 47    overcast clouds       0.00      91  2.00
# 48         few clouds       0.00      13  1.03
# 49         light rain       0.66      71  1.01
# 50    overcast clouds       0.30     100  0.59
# 51    overcast clouds       0.00      92  1.01
# 52    overcast clouds       0.00     100  0.98
# 53         light rain       0.90      67  1.00
# 54         light rain       0.20      22  1.00
# 55    overcast clouds       0.00     100  1.00
# 56         few clouds       0.00      12  0.93
# 57         light rain       0.79      63  0.56
# 58         light rain       0.20     100  0.89
# 59    overcast clouds       0.31     100  0.23
# 60    overcast clouds       0.00     100  0.67
# 61         light rain       1.00      52  1.00
# 62         few clouds       0.00      16  1.00
# 63    overcast clouds       0.00     100  1.00
# 64         light rain       0.45      74  1.05
# 65         light rain       1.00      92  0.47
# 66         light rain       1.00      99  0.86
# 67         light rain       1.00     100  0.70
# 68         light rain       0.40     100  0.48
# 69         light rain       1.00      99  1.00
# 70    overcast clouds       0.09      94  1.00
# 71    overcast clouds       0.00      92  1.00
# 72         light rain       0.45      91  0.68
# 73      rain and snow       1.00      93  0.27
# 74      rain and snow       1.00      97  0.93
# 75         light rain       1.00     100  0.55
# 76         light rain       0.55     100  0.87
# 77         light rain       1.00     100  1.00
# 78    overcast clouds       0.07      96  1.00
# 79    overcast clouds       0.00      90  1.00
# 80         light rain       0.38      82  0.68
# 81      rain and snow       1.00      98  0.27
# 82      rain and snow       1.00      98  0.93
# 83         light rain       1.00     100  0.55
# 84         light rain       0.63     100  0.87
# 85         light rain       1.00      99  1.00
# 86      broken clouds       0.17      72  1.00
# 87    overcast clouds       0.00      85  1.00
# 88         light rain       0.39      78  0.68
# 89      rain and snow       1.00      99  0.27
# 90      rain and snow       1.00      99  0.93
# 91         light rain       1.00     100  0.55
# 92         light rain       0.65      99  0.87
# 93         light rain       1.00      99  1.00
# 94      broken clouds       0.16      70  1.00
# 95    overcast clouds       0.00      89  1.00
# 96         light rain       0.36      94  1.16
# 97      rain and snow       1.00     100  0.61
# 98      rain and snow       1.00      80  1.36
# 99         light rain       1.00     100  0.54
# 100        light rain       0.25      93  1.29
# 101     moderate rain       1.00     100  2.00
# 102  scattered clouds       0.34      39  2.00
# 103     broken clouds       0.00      51  2.00
# 104   overcast clouds       0.09      86  1.11
# 105     rain and snow       0.80      99  0.77
# 106        light rain       0.95      98  1.19
# 107        light rain       0.76     100  0.47
# 108   overcast clouds       0.00      87  1.40
# 109        light rain       1.00      92  2.00
# 110  scattered clouds       0.00      27  2.00
# 111     broken clouds       0.00      66  2.00
# 112  scattered clouds       0.00      27  1.50
# 113        light snow       0.98     100  0.53
# 114     rain and snow       1.00      53  1.67
# 115     rain and snow       1.00     100  1.34
# 116   overcast clouds       0.00      88  1.61
# 117        light rain       1.00      86  2.00
# 118        light rain       0.95      40  2.00
# 119  scattered clouds       0.00      26  2.00
# 120  scattered clouds       0.00      28  1.21
# 121     rain and snow       0.72     100  0.51
# 122        light rain       0.75      35  1.72
# 123        light rain       0.86     100  1.39
# 124     broken clouds       0.00      76  1.69
# 125        light rain       0.48      36  2.00
# 126        light rain       0.32      93  2.00
# 127         clear sky       0.00      10  2.00
# 128   overcast clouds       0.00      93  1.35
# 129     rain and snow       0.63     100  0.77
# 130     rain and snow       0.65      25  1.59
# 131        light rain       0.75     100  0.43
# 132   overcast clouds       0.00      94  1.67
# 133        light rain       0.76      93  2.00
# 134        light rain       0.42       3  2.00
# 135  scattered clouds       0.00      36  2.00
# 136         clear sky       0.00       4  1.87
# 137  scattered clouds       0.00      40  1.74
# 138         clear sky       0.00       2  2.01
# 139         clear sky       0.00       2  1.96
# 140     broken clouds       0.00      66  1.94
# 141  scattered clouds       0.00      40  2.00
# 142         clear sky       0.00       2  2.00
# 143         clear sky       0.00       0  2.00
# 144         clear sky       0.00       1  1.95
# 145  scattered clouds       0.00      25  1.75
# 146         clear sky       0.00      10  2.04
# 147         clear sky       0.00       5  2.06
# 148     broken clouds       0.00      65  1.99
# 149        few clouds       0.00      20  2.00
# 150     broken clouds       0.00      82  2.00
# 151         clear sky       0.00       0  2.00
# 152         clear sky       0.00       0  1.95
# 153  scattered clouds       0.00      34  1.73
# 154        few clouds       0.00      12  2.05
# 155         clear sky       0.00       1  2.06
# 156  scattered clouds       0.00      48  1.99
# 157     broken clouds       0.00      54  2.00
# 158   overcast clouds       0.00      86  2.00
# 159         clear sky       0.00       0  2.00
# 160         clear sky       0.00       0  1.94
# 161  scattered clouds       0.00      39  1.73
# 162         clear sky       0.00       4  2.03
# 163         clear sky       0.00       1  2.05
# 164  scattered clouds       0.00      45  1.96
# 165     broken clouds       0.00      58  2.00
# 166     broken clouds       0.00      76  2.00
# 167         clear sky       0.00       0  2.00
# 168         clear sky       0.00       2  1.87
# 169  scattered clouds       0.00      43  1.71
# 170         clear sky       0.00       1  1.98
# 171         clear sky       0.00       0  1.98
# 172  scattered clouds       0.00      46  1.89
# 173     broken clouds       0.00      59  2.00
# 174  scattered clouds       0.00      40  2.00
# 175         clear sky       0.00       0  2.00
# 176         clear sky       0.00       2  1.90
# 177     broken clouds       0.00      62  1.71
# 178         clear sky       0.00       4  1.99
# 179         clear sky       0.00       1  2.01
# 180     broken clouds       0.00      52  1.89
# 181  scattered clouds       0.00      32  2.00
# 182         clear sky       0.00       2  2.00
# 183         clear sky       0.00       0  2.00
# 184         clear sky       0.00       0  1.90
# 185     broken clouds       0.00      62  1.38
# 186         clear sky       0.00       2  1.98
# 187         clear sky       0.00       2  1.12
# 188  scattered clouds       0.00      42  1.92
# 189        few clouds       0.00      19  2.00
# 190         clear sky       0.00       1  2.00
# 191         clear sky       0.00       0  2.00
# 192         clear sky       0.00       0  1.92
# 193     broken clouds       0.00      61  1.64
# 194         clear sky       0.00       2  2.03
# 195         clear sky       0.00       0  2.04
# 196  scattered clouds       0.00      35  1.91
# 197  scattered clouds       0.00      30  2.00
# 198        few clouds       0.00      15  2.00
# 199         clear sky       0.00       0  2.00
# 200         clear sky       0.00       0  1.92
# 201     broken clouds       0.00      60  1.64
# 202         clear sky       0.00       2  2.03
# 203         clear sky       0.00       0  2.04
# 204  scattered clouds       0.00      33  1.91
# 205  scattered clouds       0.00      39  2.00
# 206     broken clouds       0.00      57  2.00
# 207         clear sky       0.00       0  2.00
# 208         clear sky       0.00       0  1.89
# 209     broken clouds       0.00      57  1.75
# 210        few clouds       0.00      16  2.06
# 211         clear sky       0.00       1  2.08
# 212  scattered clouds       0.00      39  1.96
# 213  scattered clouds       0.00      49  2.00
# 214     broken clouds       0.00      61  2.00
# 215         clear sky       0.00       0  2.00
# 216         clear sky       0.00       2  1.98
# 217  scattered clouds       0.13      41  1.47
# 218         clear sky       0.05       4  2.09
# 219         clear sky       0.00       0  2.10
# 220     broken clouds       0.00      51  2.05
# 221  scattered clouds       0.00      43  3.00
# 222   overcast clouds       0.00      88  3.00
# 223         clear sky       0.00       0  3.00
# 224         clear sky       0.00       9  1.88
# 225        light rain       0.41      99  0.52
# 226     broken clouds       0.29      54  0.98
# 227     broken clouds       0.11      52  0.83
# 228     broken clouds       0.00      69  2.00
# 229        light rain       0.27      99  2.00
# 230   overcast clouds       0.00      92  2.00
# 231         clear sky       0.00       0  2.00
# 232         clear sky       0.00       2  2.01
# 233     rain and snow       0.49      94  1.06
# 234        light snow       0.49      73  1.69
# 235        few clouds       0.00      16  2.23
# 236     broken clouds       0.00      67  2.07
# 237        light rain       0.24      88  3.00
# 238   overcast clouds       0.00     100  3.00
# 239         clear sky       0.00       0  3.00
# 240         clear sky       0.00       4  1.82
# 241        light rain       0.29     100  0.87
# 242  scattered clouds       0.17      42  1.33
# 243   overcast clouds       0.02      90  1.00
# 244     broken clouds       0.00      80  1.86
# 245        light rain       0.23     100  2.00
# 246  scattered clouds       0.00      45  2.00
# 247         clear sky       0.00       0  2.00
# 248         clear sky       0.00       5  1.48
# 249   overcast clouds       0.15     100  0.78
# 250     broken clouds       0.00      62  1.03
# 251   overcast clouds       0.04      98  1.08
# 252     broken clouds       0.00      58  1.77
# 253        light rain       0.24     100  2.00
# 254         clear sky       0.00       1  2.00
# 255         clear sky       0.00       0  2.00
# 256         clear sky       0.00       0  1.85
# 257        light rain       0.91      88  1.26
# 258        light rain       0.51      57  1.45
# 259  scattered clouds       0.00      47  1.95
# 260   overcast clouds       0.00      98  1.88
# 261        light rain       0.44     100  2.00
# 262        light rain       0.29      89  2.00
# 263         clear sky       0.00       0  2.00
# 264         clear sky       0.00       0  1.88
# 265        light rain       0.90      87  1.25
# 266        light rain       0.48      55  1.70
# 267  scattered clouds       0.00      37  2.07
# 268   overcast clouds       0.00      97  1.88
# 269        light rain       0.43     100  2.00
# 270        light rain       0.27      87  2.00
# 271         clear sky       0.00       0  2.00
# 272   overcast clouds       0.00     100  0.67
# 273        light rain       0.20      64  1.42
# 274     broken clouds       0.00      72  1.55
# 275     broken clouds       0.00      75  0.72
# 276        light rain       0.20      81  1.45
# 277        light rain       0.25      67  2.00
# 278         clear sky       0.00       6  2.00
# 279     broken clouds       0.00      72  2.00

# %%
df_weather_35.to_csv('src/cities_weather.csv',index=False)

# %%
df_weather_35.weather_main.value_counts()
# Out:
# Clouds    121
# Rain       79
# Clear      63
# Snow       17
# Name: weather_main, dtype: int64

# %%
# Select best cities by weather_main and tem_day
top_cities = df_weather_35[df_weather_35["weather_main"]=="Clear"].sort_values("tem_day", ascending=False).head(5)
list_best_cities = top_cities['city'].unique()

# %%
print("According to weather main = Clear and tem_day, we could say that 5 best cities for 8 past days were : ", list_best_cities)
# Out:
# According to weather main = Clear and tem_day, we could say that 5 best cities for 8 past days were :  ['Nimes' 'Aigues Mortes' 'Saintes Maries de la mer' 'Uzes' 'Collioure']

# %% [markdown]
# ### Get hotels' info about each destination
# ##### Scrape Booking.com
#
# Since BookingHoldings doesn't have aggregated databases, it will be much faster to scrape data directly from booking.com
#
# You can scrap as many information asyou want, but we suggest that you get at least:
#
# *   hotel name,
# *   Url to its booking.com page,
# *   Its coordinates: latitude and longitude
# *   Score given by the website users
# *   Text description of the hotel

# %% [markdown]
# ### III. Scraping booking.com

# %% [markdown]
# ### Store all the information above in a data lake
# ##### Create your data lake using S3
#
# Once you managed to build your dataset, you should store into S3 as a csv file.

# %% [markdown]
# ### IV. Store files on S3 bucket

# %%
# !pip install Boto3
# Out:
# Collecting Boto3
#   Downloading boto3-1.20.46-py3-none-any.whl (131 kB)
#      |████████████████████████████████| 131 kB 9.7 MB/s eta 0:00:01
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /opt/conda/lib/python3.8/site-packages (from Boto3) (0.10.0)
# Collecting s3transfer<0.6.0,>=0.5.0
#   Using cached s3transfer-0.5.0-py3-none-any.whl (79 kB)
# Collecting botocore<1.24.0,>=1.23.46
#   Downloading botocore-1.23.46-py3-none-any.whl (8.5 MB)
#      |████████████████████████████████| 8.5 MB 61.6 MB/s eta 0:00:01
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in /opt/conda/lib/python3.8/site-packages (from botocore<1.24.0,>=1.23.46->Boto3) (1.25.10)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /opt/conda/lib/python3.8/site-packages (from botocore<1.24.0,>=1.23.46->Boto3) (2.8.1)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.8/site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.24.0,>=1.23.46->Boto3) (1.15.0)
# Installing collected packages: botocore, s3transfer, Boto3
# Successfully installed Boto3-1.20.46 botocore-1.23.46 s3transfer-0.5.0

# %%
import boto3
session = boto3.Session(aws_access_key_id="", 
                        aws_secret_access_key="")

# %%
S3 = session.resource('s3')

# %%
import csv

# %%
# put objets on the creating bucket 
object = S3.Object('fesson-bucket-kayak', 'cities_coordgps.csv').put(Body=open("src/cities_coordgps.csv", "rb"))

# %%
object2 = S3.Object('fesson-bucket-kayak','cities_weather.csv').put(Body=open("src/cities_weather.csv", "rb"))

# %% [markdown]
# ### Extract, transform and load cleaned data from your datalake to a data warehouse
# ##### ETL
#
# Once you uploaded your data onto S3, it will be better for the next data analysis team to extract clean data directly from a Data Warehouse. Therefore, create a SQL Database using AWS RDS, extract your data from S3 and store it in your newly created DB.

# %% [markdown]
# #### ID Connection to the RDS DATABASE MYSQL :
#
#     Host : fesson-kayak-db.cfemolqokjpg.eu-west-3.rds.amazonaws.com
#     Port : 3306
#     User : fessonuser
#     Password :     db : kayak
